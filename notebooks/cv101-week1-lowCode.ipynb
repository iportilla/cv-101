# %% [markdown]
# # 📘 Week 1: Computer Vision with OpenCV
#
# Welcome to your first week of computer vision!
#
# In this notebook, you’ll explore basic image processing using OpenCV.
#
# 🧰 Make sure you've installed:
# - `opencv-python`
# - `matplotlib`
# - Jupyter or JupyterLab
#
# ✅ Let’s get started!

# %%
# Import libraries
import cv2
import matplotlib.pyplot as plt
import numpy as np

print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.11.0

# %% [markdown]
# ## 1️⃣ Load and Display an Image

# %%
# Load image (replace with your image file)
img = cv2.imread('bananas.jpg')  # ← Change this to your own file name

# Convert BGR to RGB


# Display

# %% [markdown]
# ## 2️⃣ Convert to Grayscale and Apply Gaussian Blur

# %%
# gray
# blurred

# %% [markdown]
# ## 3️⃣ Edge Detection (Canny)

# %%
#edges

# %% [markdown]
# ## ✅ Challenge Task: Create a Filter Function to Apply All Steps

# %%
def process_image(img_path):
    #try it

# Try it: process_image('sample.jpg')
